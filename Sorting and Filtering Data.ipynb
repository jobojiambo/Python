# %%
import pandas as pd
my_data = pd.read_csv('happyscore_income.csv')
my_data
# Out:
#                 country  adjusted_satisfaction  avg_satisfaction  \
# 0               Armenia                     37               4.9
# 1                Angola                     26               4.3
# 2             Argentina                     60               7.1
# 3               Austria                     59               7.2
# 4             Australia                     65               7.6
# 5            Azerbaijan                     46               5.8
# 6            Bangladesh                     43               5.3
# 7               Belgium                     63               7.2
# 8          Burkina Faso                     37               4.4
# 9              Bulgaria                     34               4.6
# 10              Burundi                     25               2.9
# 11                Benin                     20               3.0
# 12              Bolivia                     53               6.3
# ...

# %%
my_data.sort_values('median_income', inplace = True)
poor = my_data['median_income']
unequal = my_data['income_inequality']
import matplotlib.pyplot as plot
plot.scatter(poor, unequal)

# %%
my_data.sort_values('median_income', inplace = True)
my_data.sort_values('income_inequality', inplace = True)
poor = my_data[my_data['median_income']<1000]
unequal = my_data[my_data['income_inequality']>35]
[poor.iloc[-1], poor.iloc[1], poor.iloc[0]]
# Out:
# [country                                Zambia
#  adjusted_satisfaction                      37
#  avg_satisfaction                            5
#  std_satisfaction                         2.61
#  avg_income                             956.76
#  median_income                          510.06
#  income_inequality                       55.12
#  region                   'Sub-Saharan Africa'
#  happyScore                              5.129
#  GDP                                   0.47038
#  country.1                              Zambia
#  Name: 109, dtype: object, country                              Ethiopia
#  adjusted_satisfaction                      33
#  avg_satisfaction                          4.2
#  std_satisfaction                         2.25
#  avg_income                            1050.72
#  median_income                          857.16
#  income_inequality                       33.17
#  region                   'Sub-Saharan Africa'
# ...

# %%
my_data.sort_values('median_income', inplace = True)
my_data.sort_values('income_inequality', inplace = True)
poor = my_data[my_data['median_income']<1000]
unequal = my_data[my_data['income_inequality']>35]
[unequal.iloc[-1], unequal.iloc[1], unequal.iloc[0]]
# Out:
# [country                          South Africa
#  adjusted_satisfaction                      49
#  avg_satisfaction                          6.3
#  std_satisfaction                         2.47
#  avg_income                            3889.32
#  median_income                          1506.4
#  income_inequality                     63.7267
#  region                   'Sub-Saharan Africa'
#  happyScore                              4.642
#  GDP                                   0.92049
#  country.1                        South Africa
#  Name: 108, dtype: object,
#  country                                     Lithuania
#  adjusted_satisfaction                              48
#  avg_satisfaction                                  5.8
#  std_satisfaction                                 2.15
#  avg_income                                    6789.16
#  median_income                                 5598.36
#  income_inequality                               35.12
# ...

# %%
my_data.sort_values('median_income', inplace = True)
my_data.sort_values('income_inequality', inplace = True)
poor = my_data[my_data['median_income']<1000]
unequal = my_data[my_data['income_inequality']>35]
unequal.iloc[0:50]
# Out:
#                 country  adjusted_satisfaction  avg_satisfaction  \
# 39               Greece                     54               6.5
# 60            Lithuania                     48               5.8
# 4             Australia                     65               7.6
# 68           Mauritania                     36               4.9
# 69            Mauritius                     48               5.9
# 66                 Mali                     32               4.7
# 62               Latvia                     45               5.5
# 58              Liberia                     37               4.4
# 84             Portugal                     47               5.8
# 100             Tunisia                     43               5.5
# 56                 Laos                     55               6.2
# 20                China                     48               6.2
# 73                Niger                     34               3.8
# ...
