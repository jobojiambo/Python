# %%
import pandas as pd
my_data = pd.read_csv('Banknote_Project')
import matplotlib.pyplot as plot
import matplotlib.patches as patches
import numpy as np

# %%
mean = np.mean(my_data)
print(mean)
# Out:
# V1    0.433735
# V2    1.922353
# dtype: float64

# %%
Standard_Deviation=np.std(my_data)
print(Standard_Deviation)
# Out:
# V1    2.841726
# V2    5.866907
# dtype: float64

# %%
Variance = np.var(my_data)
print(Variance)
# Out:
# V1     8.075409
# V2    34.420603
# dtype: float64

# %%
V1 = my_data.sort_values('V1')
V2 = my_data.sort_values('V2')
mean_1 =np.mean(my_data)
Variance_1 = np.var(my_data)
print(Variance_1)
print(mean_1)
std_dev=np.std(my_data)
ellipse =patches.Ellipse([mean_1, Variance_1], std_dev[0]*2, std_dev[1]*2, alpha=0.25)
my_data
plot.xlabel('V1')
plot.ylabel('V2')
plot.scatter(Variance_1,mean_1)
plot.scatter(V2,V1)
plot.scatter(V1,V2)
# Out:
# V1     8.075409
# V2    34.420603
# dtype: float64
# V1    0.433735
# V2    1.922353
# dtype: float64
